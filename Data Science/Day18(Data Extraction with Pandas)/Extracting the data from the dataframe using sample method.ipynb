# %%
import pandas as pd

# Create a DataFrame for all practice questions
data = {
    'ProductID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Product': ['Laptop', 'Phone', 'Tablet', 'Monitor', 'Keyboard', 
                'Mouse', 'Printer', 'Speaker', 'Headphones', 'Camera'],
    'Price': [999, 699, 349, 249, 49, 29, 199, 129, 99, 599],
    'Category': ['Electronics', 'Electronics', 'Electronics', 'Electronics',
                'Accessories', 'Accessories', 'Office', 'Audio', 'Audio', 'Electronics']
}
products_df = pd.DataFrame(data)

# Question 1: Get 3 random products from the DataFrame
# Your code here
products_df.sample(n=4,replace=True)
# Question 2: Select 30% of the products randomly without replacement
# Your code here
products_df.sample(frac=0.3)
# Question 3: Get 5 random products with replacement (allowing duplicates)
# Your code here
products_df.sample(n=5,replace=True)
# Question 4: Select 2 random Electronics products (hint: first filter by category)
# Your code here
products_df.sample(n=2)
# Question 5: Get a random sample where expensive products (>$500) have twice the chance 
# of being selected compared to cheaper ones
# Your code here
# Out:
#    ProductID  Product  Price     Category
# 9        110   Camera    599  Electronics
# 7        108  Speaker    129        Audio
