# %%
import pandas as pd

# %%
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()

# %%
import pandas as pd

# 📊 Sample Data
data = {
    'StudentID': [104, 101, 103, 102],
    'Name': ['Ali', 'Sara', 'John', 'Nina'],
    'Grade': ['B', 'A', 'C', 'B'],
    'Marks': [76, 88, 65, 80]
}

df = pd.DataFrame(data)
print("📘 Original DataFrame:\n", df)

# 🧠 PRACTICE QUESTIONS

# 1️⃣ Set 'StudentID' as the new index and print the DataFrame.
# 👉 Hint: Use set_index()
df = df.set_index('StudentID')
df
# 2️⃣ Now sort the DataFrame by the new index ('StudentID') in ascending order.
# 👉 Hint: Use sort_index()
# df_indexed.sort_index(axis=0)
# 3️⃣ Set 'Name' as the index, but DON'T drop it from the columns.
# 👉 Hint: set_index(..., drop=False)
# df_indexed.set_index('Name',drop=False)
# 4️⃣ After setting 'Name' as index, sort it in **descending order**.
# 👉 Hint: sort_index(ascending=False)
# df_indexed.set_index('Name').sort_index(ascending=False)
# 5️⃣ Restore the original DataFrame (with default 0, 1, 2 index) using reset_index().
# 👉 Bonus: Try it after you've changed the index to 'Name'.
df.reset_index()
# ✍️ Now try to solve each part step by step and use print statements to see your results!
# Out:
# 📘 Original DataFrame:
#     StudentID  Name Grade  Marks
# 0        104   Ali     B     76
# 1        101  Sara     A     88
# 2        103  John     C     65
# 3        102  Nina     B     80
#    StudentID  Name Grade  Marks
# 0        104   Ali     B     76
# 1        101  Sara     A     88
# 2        103  John     C     65
# 3        102  Nina     B     80
