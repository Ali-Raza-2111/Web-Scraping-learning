# %%
import pandas as pd
df_boston = pd.read_csv('Boston House Prices.csv')
df_boston.head()
# Out:
#    Rooms  Distance  Value
# 0  6.575    4.0900   24.0
# 1  6.421    4.9671   21.6
# 2  7.185    4.9671   34.7
# 3  6.998    6.0622   33.4
# 4  7.147    6.0622   36.2

# %%
from sklearn import linear_model
